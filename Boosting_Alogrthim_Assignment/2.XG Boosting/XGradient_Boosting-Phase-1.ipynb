# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.replace({True:1,False:0})
dataset
# Out:
# C:\Users\PRIYANKA MANI\AppData\Local\Temp\ipykernel_11144\3350150185.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:1,False:0})
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# ...

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
X_train,X_test,Y_train,Y_test
# Out:
# (      age     bmi  children  sex_male  smoker_yes
#  1163   18  28.215         0         0           0
#  196    39  32.800         0         0           0
#  438    52  46.750         5         0           0
#  183    44  26.410         0         0           0
#  1298   33  27.455         2         1           0
#  ...   ...     ...       ...       ...         ...
#  763    27  26.030         0         1           0
#  835    42  35.970         2         1           0
#  1216   40  25.080         0         1           0
#  559    19  35.530         0         1           0
#  684    33  18.500         1         0           0
#
#  [936 rows x 5 columns],
#        age     bmi  children  sex_male  smoker_yes
#  578    52  30.200         1         1           0
#  610    47  29.370         1         0           0
#  569    48  40.565         2         1           1
#  1034   61  38.380         0         1           0
#  198    51  18.050         0         0           0
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
regressor=GradientBoostingRegressor(n_estimators=50,loss='huber', criterion='squared_error', random_state=0)
regressor.fit(X_train,Y_train)
regressor
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor(criterion='squared_error', loss='huber',
#                           n_estimators=50, random_state=0)

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([10577.66288067,  9193.66422674, 44954.38151027, 13428.81723547,
#         9570.00637371,  4888.39105268,  2179.06320945, 11243.87964146,
#         6956.06860382,  5422.43219418,  6564.78262628, 10858.02972469,
#         8382.243622  ,  5096.96018352, 18549.33647018, 11243.87964146,
#        12885.02753244,  3390.77204099,  6511.41816966, 34639.40113266,
#        23289.64281993, 12620.17746073, 10875.3811273 , 24592.53781941,
#         1935.46872027,  4352.27017458,  3795.09510655,  7526.44475584,
#         3878.71139823,  8735.40593862,  7526.44475584, 47714.24628596,
#        13599.82915094, 11116.87429726, 16180.92986704,  3898.97932314,
#         8735.40593862, 36537.79120781, 39373.19653507,  2283.64455175,
#         5073.35808393,  3704.9453679 , 19758.82408443, 46527.80383653,
#        37438.62710087,  3595.2649285 , 11243.87964146,  6440.48285658,
#         4502.35095485, 11875.14042308,  3091.6230658 ,  3886.08998806,
# ...

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)
r_score
# Out:
# 0.892176082829576

# %%
import pickle
filename="finalized_Model_XG.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_Model_XG.sav",'rb'))
result=loaded_model.predict([[30,32.4,2,0.343,1.232]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([36966.08031145])
